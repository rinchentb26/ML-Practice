# %% [markdown]
# # Pandas Practice

# %%
import pandas as pd

# %%
#Creating a Pandas Series (1D)
name = pd.Series(["Rinchen","Thon","Sangay"])

# %%
#Creating a Pandas Series (1D)
age = pd.Series([21,22,22])

# %%
# Create a df(2D) using above Series
student_info = pd.DataFrame({"Name":name,"Age":age})
student_info
# Out:
#       Name  Age
# 0  Rinchen   21
# 1     Thon   22
# 2   Sangay   22

# %%
#importing csv file
df = pd.read_csv("car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#exporting df to a .csv file
df.to_csv("export.csv",index=False)

# %%
#reading that exported csv file
df = pd.read_csv("export.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#pandas attribute
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#pandas attribute
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
#pandas function
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
#pandas attribute
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#pandas function
df["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
#Creating a pd series
car_prices = pd.Series([19000,10000,23000])

# %%
#mean() on pd Series
car_prices.mean()
# Out:
# 17333.333333333332

# %%
#count() on pd Series
car_prices.count()
# Out:
# 3

# %%
#pandas method
df.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
#mean() on a specific column of df
df["Odometer (KM)"].sum()
# Out:
# 786014

# %%
#method to find length
len(df)
# Out:
# 10

# %%
#pandas method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
df.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
#creating pd Series with custom indexes
animals = pd.Series(["Gorilla","Dog","Lion","Chimpanzee","Tiger"],index= [2,3,4,2,5])
animals
# Out:
# 2       Gorilla
# 3           Dog
# 4          Lion
# 2    Chimpanzee
# 5         Tiger
# dtype: object

# %%
#loc refers index
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#iloc refers actual pos
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
#choose specific column
df["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
#condition on column
df[df["Odometer (KM)"] > 1000000]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price]
# Index: []

# %%
toyota_df = df[df["Make"] == "Toyota"]

# %%
toyota_df.dtypes
print(toyota_df)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(df["Make"],df["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
df.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
df["Doors"].hist()
# Out:
# <AxesSubplot: >

# %%
df["Make"] = df["Make"].str.lower()

# %%
df["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
missing_df = pd.read_csv("car-sales-missing-data.csv")

# %%
missing_df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_df["Odometer"].fillna(missing_df["Odometer"].mean(),inplace=True)

# %%
missing_df["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
missing_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
missing_df.dropna(inplace=True)

# %%
missing_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
missing_df.to_csv("full_data.csv")

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00

# %%
no_of_seats = pd.Series([1,2,3,4,5,6])

# %%
df["No of Seats"] = no_of_seats

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  No of Seats
# 0  toyota  White         150043      4   $4,000.00          1.0
# 1   honda    Red          87899      4   $5,000.00          2.0
# 2  toyota   Blue          32549      3   $7,000.00          3.0
# 3     bmw  Black          11179      5  $22,000.00          4.0
# 4  nissan  White         213095      4   $3,500.00          5.0
# 5  toyota  Green          99213      4   $4,500.00          6.0
# 6   honda   Blue          45698      4   $7,500.00          NaN
# 7   honda   Blue          54738      4   $7,000.00          NaN
# 8  toyota  White          60000      4   $6,250.00          NaN
# 9  nissan  White          31600      4   $9,700.00          NaN

# %%
df["No of Seats"].fillna(0,inplace=True)

# %%
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  No of Seats
# 5  toyota  Green          99213      4  $4,500.00          6.0
# 6   honda   Blue          45698      4  $7,500.00          0.0
# 7   honda   Blue          54738      4  $7,000.00          0.0
# 8  toyota  White          60000      4  $6,250.00          0.0
# 9  nissan  White          31600      4  $9,700.00          0.0

# %%
km = [1.2,3.3,3.2,4.3,2.1,45.6,23.3,5,2.3,2.5]
df["LOL"] = km

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  LOL
# 0  toyota  White         150043      4   $4,000.00  1.2
# 1   honda    Red          87899      4   $5,000.00  3.3
# 2  toyota   Blue          32549      3   $7,000.00  3.2
# 3     bmw  Black          11179      5  $22,000.00  4.3
# 4  nissan  White         213095      4   $3,500.00  2.1

# %%
df["Fuel Used (L)"] = df["Odometer (KM)"]/100 * df["LOL"]

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  LOL  Fuel Used (L)
# 0  toyota  White         150043      4   $4,000.00  1.2       1800.516
# 1   honda    Red          87899      4   $5,000.00  3.3       2900.667
# 2  toyota   Blue          32549      3   $7,000.00  3.2       1041.568
# 3     bmw  Black          11179      5  $22,000.00  4.3        480.697
# 4  nissan  White         213095      4   $3,500.00  2.1       4474.995

# %%
df.drop("LOL",axis=1,inplace=True)

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel Used (L)
# 0  toyota  White         150043      4   $4,000.00       1800.516
# 1   honda    Red          87899      4   $5,000.00       2900.667
# 2  toyota   Blue          32549      3   $7,000.00       1041.568
# 3     bmw  Black          11179      5  $22,000.00        480.697
# 4  nissan  White         213095      4   $3,500.00       4474.995

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel Used (L)
# 0  toyota  White         150043      4   $4,000.00       1800.516
# 1   honda    Red          87899      4   $5,000.00       2900.667
# 2  toyota   Blue          32549      3   $7,000.00       1041.568
# 3     bmw  Black          11179      5  $22,000.00        480.697
# 4  nissan  White         213095      4   $3,500.00       4474.995
# 5  toyota  Green          99213      4   $4,500.00      45241.128
# 6   honda   Blue          45698      4   $7,500.00      10647.634
# 7   honda   Blue          54738      4   $7,000.00       2736.900
# 8  toyota  White          60000      4   $6,250.00       1380.000
# 9  nissan  White          31600      4   $9,700.00        790.000

# %%
real_df = df.sample(frac=0.5)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Fuel Used (L)
# 0  toyota  White         150043      4   $4,000.00       1800.516
# 1   honda    Red          87899      4   $5,000.00       2900.667
# 2  toyota   Blue          32549      3   $7,000.00       1041.568
# 3     bmw  Black          11179      5  $22,000.00        480.697
# 4  nissan  White         213095      4   $3,500.00       4474.995
# 5  toyota  Green          99213      4   $4,500.00      45241.128
# 6   honda   Blue          45698      4   $7,500.00      10647.634
# 7   honda   Blue          54738      4   $7,000.00       2736.900
# 8  toyota  White          60000      4   $6,250.00       1380.000
# 9  nissan  White          31600      4   $9,700.00        790.000

# %%
real_df
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Fuel Used (L)
# 0  toyota  White         150043      4  $4,000.00       1800.516
# 1   honda    Red          87899      4  $5,000.00       2900.667
# 9  nissan  White          31600      4  $9,700.00        790.000
# 7   honda   Blue          54738      4  $7,000.00       2736.900
# 4  nissan  White         213095      4  $3,500.00       4474.995

# %%
real_df.reset_index(inplace=True,drop =True)

# %%
real_df
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Fuel Used (L)
# 0  toyota  White         150043      4  $4,000.00       1800.516
# 1   honda    Red          87899      4  $5,000.00       2900.667
# 2  nissan  White          31600      4  $9,700.00        790.000
# 3   honda   Blue          54738      4  $7,000.00       2736.900
# 4  nissan  White         213095      4  $3,500.00       4474.995

# %%
real_df
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Fuel Used (L)
# 0  toyota  White         150043      4  $4,000.00       1800.516
# 1   honda    Red          87899      4  $5,000.00       2900.667
# 2  nissan  White          31600      4  $9,700.00        790.000
# 3   honda   Blue          54738      4  $7,000.00       2736.900
# 4  nissan  White         213095      4  $3,500.00       4474.995

# %%
real_df["Odometer (Miles)"] = real_df["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
real_df
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Fuel Used (L)  \
# 0  toyota  White         150043      4  $4,000.00       1800.516
# 1   honda    Red          87899      4  $5,000.00       2900.667
# 2  nissan  White          31600      4  $9,700.00        790.000
# 3   honda   Blue          54738      4  $7,000.00       2736.900
# 4  nissan  White         213095      4  $3,500.00       4474.995
#
#    Odometer (Miles)
# 0         93776.875
# 1         54936.875
# 2         19750.000
# 3         34211.250
# 4        133184.375

# %%
real_df.drop("Odometer (KM)",axis=1,inplace=True)

# %% [markdown]
# real_df

# %%
real_df
# Out:
#      Make Colour  Doors      Price  Fuel Used (L)  Odometer (Miles)
# 0  toyota  White      4  $4,000.00       1800.516         93776.875
# 1   honda    Red      4  $5,000.00       2900.667         54936.875
# 2  nissan  White      4  $9,700.00        790.000         19750.000
# 3   honda   Blue      4  $7,000.00       2736.900         34211.250
# 4  nissan  White      4  $3,500.00       4474.995        133184.375
